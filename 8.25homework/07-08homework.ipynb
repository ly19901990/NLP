# %%
import pandas as pd
import numpy as np
import jieba
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets

# %%
fname = 'C:/Users/MWHREVO/Desktop/人工智能与NLP/jupyters_and_slides/2019-summer/sqlResult_1558435.csv'

# %%
data = pd.read_csv(fname, encoding='gb18030')

# %%
data['source'] = data['source'].fillna('')
data_pos = data[data['source'].str.contains('新华')]
data_neg = data[data['source'].str.contains('新华') == 0]

N_sample = 6000
data_neg = data_neg.sample(n = (int)(N_sample/2))
data_pos = data_pos.sample(n = (int)(N_sample/2))

data_sampled = data_pos.append(data_neg)
print(len(data_sampled))
# Out:
# 6000

# %%
attributes = ['content','feature', 'title','author','url']
attr_choosen = ['content']
def cut(string):
    return ' '.join(jieba.cut(re.sub(r'[^\w\s]',' ',string.strip())))
def preprocess(data):
    for attr in attributes:
        data[attr] = data[attr].fillna('').apply(cut)
    data['is_xinhua'] = np.where(data['source'].str.contains('新华'),1,0)
    #print(data)
    x_inputs = data.loc[:,attr_choosen]
    #print(x_inputs)
    y_inputs = data['is_xinhua'].values
    #print(y_inputs)
    return x_inputs,y_inputs
x_inputs, y_inputs = preprocess(data_sampled)       
#print(data_processed)

# %%
def vectorize(x_inputs, attr_choosen):
    vectorizer = TfidfVectorizer(max_features=5000, token_pattern=r"(?u)\b\w+\b", max_df = 1.0,
                                 stop_words = None,vocabulary = None )# (?u)进入re.u，unicode匹配模式，https://stackoverflow.com/questions/35043085/what-does-u-do-in-a-regex
    vec = None
    for attr in attr_choosen:
        vec_fea = vectorizer.fit_transform(x_inputs[attr].values)
        print("vocabulary\n",vectorizer.vocabulary_, len(vectorizer.vocabulary_))
        print("stop_words\n",vectorizer.stop_words_, len(vectorizer.stop_words_))
        #typeof(vec_fea)
        #np_vec = np.array(vec_fea)
        np_vec = vec_fea.toarray()
        #print(np_vec)
        if vec is None:
            vec = np_vec
        else:
            vec = np.hstack((vec,np_vec))
        #print(attr, vec_fea.shape, np_vec.shape)
    return vec

x_vecs = vectorize(x_inputs, attr_choosen)
print(x_vecs.shape)
# Out:
# vocabulary
#  {'新华社': 2818, '照片': 3409, '外代': 1763, '2017': 59, '年': 2199, '6': 113, '月': 2969, '2': 44, '日': 2867, 'n': 176, '二线': 587, '网球': 3945, '法网': 3271, '晋级': 2923, 'n6': 181, '1': 9, '比赛': 3197, '中': 436, '回球': 1606, '当日': 2312, '在': 1661, '法国巴黎': 3263, '举行': 520, '的': 3589, '法国': 3262, '公开赛': 967, '第二轮': 3804, '选手': 4609, '比': 3189, '0': 0, '战胜': 2487, '德国': 2358, '第三轮': 3798, '欧新': 3148, '４': 4977, '２': 4975, '３': 4976, '日电': 2876, '记者': 4275, '汉语': 3230, '桥': 3119, '世界': 385, '大学生': 1803, '中文': 462, '中国': 447, '驻': 4925, '大使馆': 1791, '本次': 3030, '主题': 515, '为': 487, '梦想': 3123, '未来': 3014, '分为': 1088, '演讲': 3374, '知识': 3662, '和': 1547, '表演': 4185, '个': 430, '环节': 3478, '来自': 3076, '大学': 1802, '学院': 1927, '语言': 4329, '等': 3807, '机构': 3046, '０': 4973, '多名': 1776, '参加': 1349, '了': 560, '们': 713, '从': 685, '各自': 1469, '生活': 3525, '讲述': 4280, '自己': 4046, '与': 369, '观众': 4218, '分享': 1089, '喜欢': 1582, '通过': 4627, '学习': 1919, '故事': 2757, '则': 1117, '希望': 2166, '成为': 2452, '一名': 209, '老师': 3976, '做': 874, '交流': 619, '桥梁': 3120, '涵盖': 3329, '还': 4540, '增加': 1727, '汉字': 3229, '需要': 4827, '根据': 3112, '看到': 3639, '英文': 4101, '对应': 2017, '准备': 1052, '太极拳': 1839, '舞蹈': 4070, '文化': 2794, '致辞': 4066, '是': 2913, '两': 411, '国': 1628, '友谊': 1361, '文化交流': 2795, '更好': 2945, '地': 1666, '了解': 561, '经济': 3893, '发展': 1383, '承担': 2549, '增进': 1733, '合作': 1472, '友好': 1360, '完': 1943, '这': 4545, '队伍': 4748, '等待': 3808, '什么': 671, '实际上': 1976, '这是': 4558, '北京': 1234, '家园': 1999, '项目': 4855, '登记': 3578, '现场': 3485, '其中': 998, '有': 2973, '房源': 2501, '专门': 380, '面向': 4844, '新': 2809, '人': 645, '吸引': 1525, '很多': 2340, '关注': 990, '王': 3462, '编辑': 3934, '日内瓦': 2868, '5': 100, '28': 71, '体育': 779, '3': 73, '夺冠': 1852, 'n5': 180, '27': 70, '瑞士': 3512, '后': 1505, '庆祝': 2232, '男单': 3558, '决赛': 1046, '以': 700, '夺得': 1853, '冠军': 1037, '发': 1377, '摄': 2702, '日前': 2869, '决定': 1043, '同志': 1491, '任': 720, '黑龙江': 4968, '省委': 3632, '委员': 1890, '常委': 2178, '书记': 554, '不再': 344, '担任': 2586, '职务': 3994, '4': 87, '男': 3557, '11': 22, '12': 30, '8': 138, '工作': 2117, '飞机': 4887, '系': 3840, '设计': 4291, '专业': 374, '毕业': 3200, '研究员': 3677, '09': 8, '08': 7, '所': 2503, '助理': 1213, '工程师': 2126, '10': 10, '一部': 264, '总体': 2393, '室': 1993, '高级': 4954, '主任': 496, '设计师': 4292, '载人': 4498, '航天': 4071, '工程': 2125, '副': 1176, '院长': 4791, '06': 5, '总经理': 2402, '技术': 2552, '业务': 394, '成员': 2458, '2007': 49, '2008': 50, '探测': 2657, '领导小组': 4873, '大型': 1797, '客机': 1989, '兼': 1011, '中央': 454, '人才': 657, '协调': 1278, '小组': 2050, '国家': 1638, '信息化': 844, '01': 2, '2011': 53, '有限责任': 2994, '公司': 955, '董事长': 4147, '党委书记': 922, '国务院': 1635, '重大': 4681, '专项': 381, '2012': 54, '省政府': 3634, '十八': 1256, '届': 2084, '中国共产党': 449, '资料': 4401, '2013': 55, '南京': 1290, '20': 45, '原': 1332, 'n4': 179, '拍摄': 2597, '江苏省': 3235, '人民法院': 663, '公开': 965, '中共': 440, '６': 4979, '１': 4974, '随着': 4802, '支持': 2717, '西藏': 4207, '重点': 4684, '顺利': 4856, '推进': 2676, '高原': 4937, '迎来': 4527, '阶段': 4763, '截至': 2490, '目前': 3608, '家': 1995, '企业': 726, '累计': 3847, '５': 4978, '多个': 1771, '落实': 4140, '资金': 4409, '逾': 4634, '亿元': 669, '众多': 733, '先后': 900, '落户': 4141, '引擎': 2281, '召开': 1439, '助力': 1211, '会议': 746, '暨': 2937, '战略': 2486, '签约': 3814, '仪式': 712, '上': 299, '到': 1145, '表示': 4187, '经济社会': 3895, '重要': 4686, '力量': 1180, '有力': 2978, '促进': 827, '提升': 2684, '公共服务': 954, '保障': 838, '水平': 3223, '电力': 3542, '通信': 4619, '基本': 1714, '提供': 2680, '有关': 2976, '不断': 358, '力度': 1179, '建成': 2252, '藏': 4151, '联网': 4004, '铁路': 4711, '基础设施': 1719, '极大': 3084, '改善': 2737, '当地': 2307, '生产': 3517, '条件': 3069, '此外': 3165, '县': 1347, '以来': 709, '投入': 2565, '超': 4439, '助推': 1212, '民生': 3208, '深度': 3338, '参与': 1348, '建设': 2256, '有效': 2982, '带动': 2169, '扩大': 2537, '就业': 2064, '据': 2643, '签订': 3816, '一系列': 251, '协议': 1277, '完成': 1946, '各类': 1467, '投资': 2571, '８': 4981, '职工': 3995, '占': 1301, '总数': 2397, '比例': 3191, '达': 4514, '毕业生': 3201, '群众': 3971, '今后': 676, '将': 2036, '加大': 1193, '全面': 948, '深化': 3335, '合资': 1484, '产品': 629, '品牌': 1552, '走': 4422, '出去 ...
# stop_words
#  {'刘宏冰', '千钧一发', '连成一片', '张平', '限时', '变差', '线转', '图纸', '李浩', '宰前', '96722', '雪铁龙', '田径项目', '抓进来', '去年末', '勒夫', '松江', '酷酷', '副本', 'visa', '某要', '高企', '黄磊', '苏州', '开得准', '小学文化', '受得了', 'ota', '相接', 'cz6677', '多册', '纠葛', '教育方针', '楝树', '承前启后', '杨博涵', '罚进', '蔡办', '官冲村', '冬奥会', '多考', '千镇', '敦善', 'angellaw', '真学实', '训练室', '法学硕士', '蓄着', '第四个', '2044', '东向西', '演示', '特种兵', '展望未来', '热干面', '王杰', '田婷', '起点站', '敌不过', '财季', '情报机构', '韩籍', '爱花', '爆炸案', '懂', '鸳鸯锅', '菜式', '五毛', '低配', '约会', '光大银行', '抽答', '帐通', '冰厂', '可视', '王肖龙', '主权国家', '天津大学', '谓', '郴', '圣詹姆斯', '商务部长', '风行一时', '护甲', '罗卡', '基里巴斯', '解决办法', '明波村', '最先', '清一色', '实实', '正餐', '催讨', '下池', '仅靠', '淘系', '珠宝', '杀一儆百', '安立路', '参警', '小情', '590', '留坝', '木地板', '和棋', '熊春庚', '2418', '豪华车', '舟白', '逊', '大雨如注', '农艺', '一黑', 'ltps', '优拜', '警员', '伊达尔戈', '问过', '麦时', '一包', 'bilal', '枪械', '成才', '时起', '否认', '基节', '辨认', '日趋激烈', '地求', '鲁迪', '酮症', '而积', '尼尔', '卢永慧', '远不止', '胡志明市', '刘凯健', '查卷', '四倍', '市场推广', '辛勤努力', '001', '真毁', '根扎', '情报工作', '教育权', '承载', '千行', '吉祥物', 'karan', '副组长', '生活报', '大彻大悟', '角度看', '顺走', '数在', '雷科', '五场', '信誉', 'n2001', '离散', '3118', '精功', '房屋中介', '常林', '车首', '私下', '缓兵之计', '引以为豪', '大项', '全食', '孰料', '展对', '那就好', '费尔通', '越加', '刘静', '更实', '许冰', '苦干', 'ax100', '汉娜', 'core', '摒弃', '屋主', '篇文章', '女法官', '五周', '云海', '扶贫济困', '华庭', 'lepen', '何须', '大赞', '华兴', '二生', '二类', '瓦兰于', '领土完整', '干越', '人性', '节能灯', '内湖区', '牛车', '合练', '众治', '之誉', 'farfetch', '陕北', '博主', '专营', '德米凯利斯', '寄望', '景甜', '面塑', 'deepmind', 'roux', '用餐', '传统服装', '癌症', '总指挥部', '弱点', '粘性', '死死', '新气象', '趁乱', 'bloomberg', '成利军', '世界银行', '哇', '宋薇萍', '绝大部分', '郑渊洁', '各组', '注册费', '西南政法大学', '居住权', '文件精神', '国所定', '新增额', '1966', '茶厂', '爆发性', '对公', '经手', '乱讲', '2700', 'flashvideo', '孝道', '跨湖', '0501', '逆向行驶', '普通本科', '次射', '彭睿婕', '永范村', '不慈', '闺蜜', '粉饰', '而后', '吕聪', '明光', '男主人', '王振有', '严歌苓', '疤', '短短', '搅乱', '观光季', '食品卫生', '李虎成', '药商', '五水共治', '汽笛', '素雅', 'star', '真情实感', '负荷', '其身', '东川区', '全川', '免填单', '街长', '常是', '水塔', '牧羊犬', '十年寒窗', '消灭', '行级', '晚睡', '包装物', 'jetstar', '努力实现', '技术规程', '福建队', '衍生品', '趁伊', '虎牙', '刑案', '抬起', '经文', '缜密', '库茨', '澳凯', '地貌学', '胞姐', '基督徒', '洛佩斯', '长途', '入住率', '粗星', '喷药', '贪污', '无望', '离底', '陷对', '切记', '天鹅湖', '漏雨', '稳定度', '有染', '勒紧', '支气管镜', '主线', '金钥匙', '济南军区', '算术平均', '名村', '指标性', '刘肖坤', '比拼', '安逸', '基多', '公证员', '长们', '泛锐', '大米', '实至名归', '调门', '翻倍', '嘴笑', '依依不舍', '姥姥', '步其后尘', '鱼叉', '最不舍', '2bp', '6065', '俄罗斯国际文传电讯社', '000565', '优良品种', '机会主义', '开二村', '斯奈德', '亲姐姐', '不及格', '谭公诞', '关子', '训竞', '书刊', '快餐店', '归纳', '潘锡朋', '冠状动脉', '学而用', '2265', '单期', '尼科尔斯', '买方', '起涉', '咏梅', '盼望', '⑨', '二十世纪', '细腰', '迎峰', '功能完善', '避暑', '梯次', '气度', '广揽', '纸包不住火', '指报', '耶夫', '赵和靖', '当吉仁', '加紧', 'patch', '科技节', '屈原', '技术手段', '6780', '付敏', '北京公交', '推特上', '研磨', '闻名于世', '央广', '五提', '面棒', '现代舞', '利用自身', '哈雷', 'facebook', '展藤', '二十', '李世民', '蚊帐', '大红门', '绿树成荫', '投身', '啊啊啊', '团专', '美国劳工部', '叫车', '吴郑', '绕林百欣', '企划', '松山湖', '来回', '8054', '薪火', '道工序', '86510725', '移居', '西南方', '相约', '辨别', '芬兰队', '不止一次', '样样', '结块', '不明不白', '练过', 'aliajoy', '伤亡', '承东启', '拉尔夫', 'woolwich', '陈奕迅', '放管', '捆绑', '宝马', '得力助手', '雷米', '贝聿铭', '链断裂', '襄州', '摘', '2600', '抛压盘', '主推', '600621', '不亚于', '侨务委员', '重庆市', '秘境', '轴向', '雨棚', '委屈', '万线', '稍加', '青金石', '蓝筹股', '3712', '清醮', '做定', '共富', '自振', '徐石', '元进', '充', '出油来', '观察报', '人民网', '两季', '青年人', '每股', '中国工农红军', '平均工资', '濒临破产', '毁掉', '荣誉证书', '邀功', '武在', '汇回', '坐牢', '可累', '倒挂金钩', '分房', '政称', '中国专利', '工商业', '成绩排名', '爱华', '推进改革', '结剂', 'n2018', '委托书', '户政', '冬奥', '颗籽', '集卡', '十余项', '复印件', '阿木拉', '拐杖', '要行', '家酒', '打基础', '中州', '常规', '同江', '8670', '黄骅港', '令美豆', '男团', '德米', '战略思维', '下大力气', '四季常青', '象牙', '各年级', '泰罗', '党工委', '钢箱梁', '原话', '林晓蔚', '过过瘾', '节育环', '邮件地址', '合金', '瓦片', '已远超', '国海', '在精神上', '装睡', '误炸', 'cac', '坐式', '我心', '分队长', '连斩', '莹莹', '凌圩村', '663', '果率', '通泄', '五是', '要变', '炭化', '李智建', '俄外长', '推拉', '辗转反侧', '银价', '悲惨', '显', '演变成', '但梅', '路向', '攒', '鸡头', '点开', '调制', '各种因素', '恶果', '笔共', '营业厅', '浇筑', '行者', '接力棒', '立查', '阴雨天', '亚喀巴湾', '代劳', '北改', '指奸', '帮帮', '留有', '过渡期', '宣教', '玩不起', '鸡翅', '拍马屁', '国宾', '实地调查', '罗卓谦', '达尔文港', '片花', '犀牛' ...
# (6000, 5000)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(
    x_vecs , y_inputs, train_size = 0.8, test_size=0.2)

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

def get_performance(model, x_, y_):
    y_hat = model.predict(x_)
    print('f1_score is: {}'.format(f1_score(y_, y_hat)))
    print('accuracy is: {}'.format(accuracy_score(y_, y_hat)))
    print('percision is: {}'.format(precision_score(y_, y_hat)))
    print('recall is: {}'.format(recall_score(y_, y_hat)))
    #print('roc_auc is: {}'.format(roc_auc_score(y_, y_hat)))
    #print('confusion matrix: \n{}'.format(confusion_matrix(y_, y_hat, labels=[0, 1])))

# %%
def train_model(model):
    model.fit(x_train, y_train) # fit model
    return get_performance(model, x_test, y_test)

# %%
model = LogisticRegression()
res_score = train_model(model)
# Out:
# D:\workappp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# f1_score is: 0.9822926374650512
# accuracy is: 0.9841666666666666
# percision is: 1.0
# recall is: 0.9652014652014652

# %%
model = LogisticRegression()
res_score = train_model(model)
# Out:
# f1_score is: 0.9822926374650512
# accuracy is: 0.9841666666666666
# percision is: 1.0
# recall is: 0.9652014652014652
# D:\workappp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
for i in np.linspace(0.1, 2, 5):
    model = LogisticRegression(C=i)
    res_score = train_model(model)
    print('*'*100)
# Out:
# D:\workappp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\workappp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# f1_score is: 0.9590865842055185
# accuracy is: 0.9641666666666666
# percision is: 0.998019801980198
# recall is: 0.9230769230769231
# ****************************************************************************************************
# f1_score is: 0.9785247432306257
# accuracy is: 0.9808333333333333
# percision is: 0.9980952380952381
# recall is: 0.9597069597069597
# ****************************************************************************************************
# D:\workappp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\workappp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# f1_score is: 0.9822926374650512
# accuracy is: 0.9841666666666666
# percision is: 1.0
# recall is: 0.9652014652014652
# ****************************************************************************************************
# f1_score is: 0.9832402234636871
# accuracy is: 0.985
# percision is: 1.0
# recall is: 0.967032967032967
# ****************************************************************************************************
# f1_score is: 0.9841860465116279
# accuracy is: 0.9858333333333333
# percision is: 1.0
# recall is: 0.9688644688644689
# ****************************************************************************************************
# D:\workappp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
model = MultinomialNB()
res_score = train_model(model)
# Out:
# f1_score is: 0.8118811881188119
# accuracy is: 0.81
# percision is: 0.7387387387387387
# recall is: 0.9010989010989011

# %%
model = DecisionTreeClassifier(max_depth=50, max_features=3000)
res_score = train_model(model)
# Out:
# f1_score is: 0.995433789954338
# accuracy is: 0.9958333333333333
# percision is: 0.9927140255009107
# recall is: 0.9981684981684982
